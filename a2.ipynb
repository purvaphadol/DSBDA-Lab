# %% [markdown]
# Perform the following operations using Python by creating student performance dataset.
# 1. Display Missing Values.
# 2. Replace missing values using any 2 suitable.
# 3. Identify outliers using boxplot and scatterplot.
# 4. Handle outlier using any technique.
# 5. Perform any 2 data normalization technique.

# %%
# Import the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Read the csv file
df = pd.read_csv("academicperformance.csv")
df
# Out:
#     Roll                             Name  Femarks  SEMarks  Temarks  Bemarks
# 0      1              Aage Raksha Gajanan     8.40     8.60     9.80     9.90
# 1      2               Ahire Anuja Sanjay     8.14     8.14     9.32     9.82
# 2      3          Ajare Ashiya Nasaruddin     6.61     6.61     9.14     9.14
# 3      4          Amrutkar Roshani Suresh     7.20     7.30     8.90      NaN
# 4      5            Attarde Komal Bhagwan     7.05     7.45     9.05     9.40
# 5      6        Avhad Pushkaraj Laxmikant      NaN     8.00     7.91     7.84
# 6      7           Aware Priti Balkrushna     8.27     8.50     9.68     9.14
# 7      8               Barse Rutuja Kiran     8.68     9.00     9.59     9.66
# 8      9          Baviskar Pratham Pravin     7.64     7.64     9.18     9.39
# 9     10            Bhalerao Tejal Pradip     9.09     9.36     9.91     9.95
# 10    11            Borse Sharvari Rajesh     7.45     7.91     9.41     9.41
# 11    12  Charak Mehul Singh Bharat Singh     9.00     9.50     9.77     9.86
# 12    13     Chaudhari Hrishikesh Subhash     9.00     9.27     9.77     9.33
# 13    14             Chavan Janhavi Gokul     7.59     7.95     9.05     9.66
# 14    15           Chavan Shraddha Rajesh     6.36     6.59     8.50     8.59
# 15    16             Chavhan Divya Bhikan     8.04      NaN     9.59     9.66
# 16    17              Danej Sakshi Ganesh     8.68     8.77     9.68     9.82
# 17    18              Dasnur Tejas Valmik     8.71     8.91     9.86     9.84
# 18    19              Deore Atharva Mohan     6.25     6.89      NaN     7.20
# 19    20           Deore Mrunal Yashavant     8.32     9.00     9.55     9.48
# 20    21           Desai Pruthvij Prakash     9.09     9.40     9.64     9.64
# 21    22        Deshpande Ojas Shailendra     7.80     8.14     9.50     9.71
# 22    23             Dixit Kedar Rajendra     8.82     9.23     9.82     9.82
# 23    24             Gangurde Dipak Dilip     8.68     9.42     9.86     9.82
# 24    25         Gite Pratiksha Balasaheb     9.42     9.55     9.05     9.18
# 25    26          Hengade Abhishek Yogesh     7.14     7.14     9.30     9.05
# 26    27                Jaju Gauri Jayesh     8.81     9.18     8.86     9.09
# 27    28          Jambhulkar Sweta Rajesh     7.31     8.38     9.36     9.00
# 28    29              Jangam Pranav Suraj     7.00     7.66     8.60     8.91
# 29    30       Kaklij Pratiksha Dadasaheb     8.87     8.77     9.44     9.66
# 30    31              Kale Ashwini Sanjay     8.95     9.16     9.59     9.89
# 31    32              Kapse Chaitali Arun     9.13     9.36     9.86     9.78
# 32    33            Khairnar Tejas Dadaji    95.00    95.00     9.40     9.90
# 33    34           Khatale Ritesh Navnath     9.02     9.20     9.30     9.45
# 34    35               Khond Ameya Satish     8.80     9.16     9.50     9.90
# 35    36      Kodmelwar Koustubh Rajendra     8.50     8.75     9.64     9.61
# 36    37           Kulkarni Rugved Manish     7.60     7.80     9.75    10.00
# 37    38              Kulkarni Soham Arun     8.66     8.66     9.66     9.66
# 38    39                 Kuwar Raj Eknath     6.63     6.82     9.23     9.23
# 39    40             Mahale Shreya Sanjay      NaN     0.00     9.86     9.91
# 40    41               More Siddhi Sudhir     0.00     0.00     9.59     9.59
# 41    42             Mulay Shreyas Nilesh     7.54     7.86     9.23     9.45
# 42    43              Nerkar Mansi Dinesh     8.25     8.80     9.00     9.25
# 43    44             Nimase Aditya Sachin     8.10     8.10     9.50     9.70
# 44    45           Pagar Ashartha Santosh     7.90     8.34     9.70     9.70
# 45    46                 Patel Jaid Aslam     0.00      NaN     8.50     9.14
# 46    47               Patel Janvi Satish     8.95     9.10     9.67     9.00
# 47    48              Patil Archit Dinesh     7.25     7.51     8.68     8.98
# 48    49             Patil Jayesh Prakash     7.40     8.00     9.50     9.10
# 49    50                   Patil Om Nitin     0.00     0.00     8.30     8.50
# 50    51        Patil Priyanka Lalitkumar     8.98     9.45     9.61     9.61
# 51    52               Patil Vedant Vijay     8.61     9.25     9.21     9.40
# 52    53           Patole Tanisha Prakash     4.00     8.00     9.00      NaN
# 53    54             Pawar Devshree Kiran     8.90     9.10     9.20     9.20
# 54    55           Pawar Dhanshree Deepak     7.13     6.60     9.04     9.45
# 55    56            Pawar Manish Sahebrao     8.55     8.64     9.73     9.80
# 56    57              Phadol Purva Gorakh     7.27     7.83     9.55     9.13
# 57    58        Rabade Vishal Chandrasing     9.54    10.00     9.45     9.54
# 58    59            Ratnaparkhi Raj Ashok     8.59      NaN     9.63     9.56
# 59    60             Ravte Rohit Ukhardya     0.00     0.00     5.00     9.36

# %% [markdown]
# 1. Display Missing Values.

# %%
df.isnull().sum()
# Out:
# Roll       0
# Name       0
# Femarks    2
# SEMarks    3
# Temarks    1
# Bemarks    2
# dtype: int64

# %%
#Select Rows with NaN Values in Any Column 
df[df.isnull().any(axis=1)]
# Out:
#     Roll                       Name  Femarks  SEMarks  Temarks  Bemarks
# 3      4    Amrutkar Roshani Suresh     7.20     7.30     8.90      NaN
# 5      6  Avhad Pushkaraj Laxmikant      NaN     8.00     7.91     7.84
# 15    16       Chavhan Divya Bhikan     8.04      NaN     9.59     9.66
# 18    19        Deore Atharva Mohan     6.25     6.89      NaN     7.20
# 39    40       Mahale Shreya Sanjay      NaN     0.00     9.86     9.91
# 45    46           Patel Jaid Aslam     0.00      NaN     8.50     9.14
# 52    53     Patole Tanisha Prakash     4.00     8.00     9.00      NaN
# 58    59      Ratnaparkhi Raj Ashok     8.59      NaN     9.63     9.56

# %% [markdown]
# 2. Replace missing values using any 2 suitable.

# %%
#The fillna() method replaces the NULL values with a specified value (here replace with 0 (zero)).
df['Femarks'].fillna(0, inplace=True)
df
# Out:
# C:\Users\purva\AppData\Local\Temp\ipykernel_22868\1387880031.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Femarks'].fillna(0, inplace=True)
#     Roll                             Name  Femarks  SEMarks  Temarks  Bemarks
# 0      1              Aage Raksha Gajanan     8.40     8.60     9.80     9.90
# 1      2               Ahire Anuja Sanjay     8.14     8.14     9.32     9.82
# 2      3          Ajare Ashiya Nasaruddin     6.61     6.61     9.14     9.14
# 3      4          Amrutkar Roshani Suresh     7.20     7.30     8.90      NaN
# 4      5            Attarde Komal Bhagwan     7.05     7.45     9.05     9.40
# 5      6        Avhad Pushkaraj Laxmikant     0.00     8.00     7.91     7.84
# 6      7           Aware Priti Balkrushna     8.27     8.50     9.68     9.14
# 7      8               Barse Rutuja Kiran     8.68     9.00     9.59     9.66
# 8      9          Baviskar Pratham Pravin     7.64     7.64     9.18     9.39
# 9     10            Bhalerao Tejal Pradip     9.09     9.36     9.91     9.95
# 10    11            Borse Sharvari Rajesh     7.45     7.91     9.41     9.41
# 11    12  Charak Mehul Singh Bharat Singh     9.00     9.50     9.77     9.86
# 12    13     Chaudhari Hrishikesh Subhash     9.00     9.27     9.77     9.33
# 13    14             Chavan Janhavi Gokul     7.59     7.95     9.05     9.66
# 14    15           Chavan Shraddha Rajesh     6.36     6.59     8.50     8.59
# 15    16             Chavhan Divya Bhikan     8.04      NaN     9.59     9.66
# 16    17              Danej Sakshi Ganesh     8.68     8.77     9.68     9.82
# 17    18              Dasnur Tejas Valmik     8.71     8.91     9.86     9.84
# 18    19              Deore Atharva Mohan     6.25     6.89      NaN     7.20
# 19    20           Deore Mrunal Yashavant     8.32     9.00     9.55     9.48
# 20    21           Desai Pruthvij Prakash     9.09     9.40     9.64     9.64
# 21    22        Deshpande Ojas Shailendra     7.80     8.14     9.50     9.71
# 22    23             Dixit Kedar Rajendra     8.82     9.23     9.82     9.82
# 23    24             Gangurde Dipak Dilip     8.68     9.42     9.86     9.82
# 24    25         Gite Pratiksha Balasaheb     9.42     9.55     9.05     9.18
# 25    26          Hengade Abhishek Yogesh     7.14     7.14     9.30     9.05
# 26    27                Jaju Gauri Jayesh     8.81     9.18     8.86     9.09
# 27    28          Jambhulkar Sweta Rajesh     7.31     8.38     9.36     9.00
# 28    29              Jangam Pranav Suraj     7.00     7.66     8.60     8.91
# 29    30       Kaklij Pratiksha Dadasaheb     8.87     8.77     9.44     9.66
# 30    31              Kale Ashwini Sanjay     8.95     9.16     9.59     9.89
# 31    32              Kapse Chaitali Arun     9.13     9.36     9.86     9.78
# 32    33            Khairnar Tejas Dadaji    95.00    95.00     9.40     9.90
# 33    34           Khatale Ritesh Navnath     9.02     9.20     9.30     9.45
# 34    35               Khond Ameya Satish     8.80     9.16     9.50     9.90
# 35    36      Kodmelwar Koustubh Rajendra     8.50     8.75     9.64     9.61
# 36    37           Kulkarni Rugved Manish     7.60     7.80     9.75    10.00
# 37    38              Kulkarni Soham Arun     8.66     8.66     9.66     9.66
# 38    39                 Kuwar Raj Eknath     6.63     6.82     9.23     9.23
# 39    40             Mahale Shreya Sanjay     0.00     0.00     9.86     9.91
# 40    41               More Siddhi Sudhir     0.00     0.00     9.59     9.59
# 41    42             Mulay Shreyas Nilesh     7.54     7.86     9.23     9.45
# 42    43              Nerkar Mansi Dinesh     8.25     8.80     9.00     9.25
# 43    44             Nimase Aditya Sachin     8.10     8.10     9.50     9.70
# 44    45           Pagar Ashartha Santosh     7.90     8.34     9.70     9.70
# 45    46                 Patel Jaid Aslam     0.00      NaN     8.50     9.14
# 46    47               Patel Janvi Satish     8.95     9.10     9.67     9.00
# 47    48              Patil Archit Dinesh     7.25     7.51     8.68     8.98
# 48    49             Patil Jayesh Prakash     7.40     8.00     9.50     9.10
# 49    50                   Patil Om Nitin     0.00     0.00     8.30     8.50
# 50    51        Patil Priyanka Lalitkumar     8.98     9.45     9.61     9.61
# 51    52               Patil Vedant Vijay     8.61     9.25     9.21     9.40
# 52    53           Patole Tanisha Prakash     4.00     8.00     9.00      NaN
# 53    54             Pawar Devshree Kiran     8.90     9.10     9.20     9.20
# 54    55           Pawar Dhanshree Deepak     7.13     6.60     9.04     9.45
# 55    56            Pawar Manish Sahebrao     8.55     8.64     9.73     9.80
# 56    57              Phadol Purva Gorakh     7.27     7.83     9.55     9.13
# 57    58        Rabade Vishal Chandrasing     9.54    10.00     9.45     9.54
# 58    59            Ratnaparkhi Raj Ashok     8.59      NaN     9.63     9.56
# 59    60             Ravte Rohit Ukhardya     0.00     0.00     5.00     9.36

# %%
# Finding the mean of the column having NaN
#The fillna() method replaces the NULL values with a specified value (here replace with mean).
mean_value = df['SEMarks'].mean()
print(mean_value)
# Out:
# 9.346491228070178

# %%
df['SEMarks']=df['SEMarks'].fillna(mean_value)
df
# Out:
#     Roll                             Name  Femarks    SEMarks  Temarks  \
# 0      1              Aage Raksha Gajanan     8.40   8.600000     9.80
# 1      2               Ahire Anuja Sanjay     8.14   8.140000     9.32
# 2      3          Ajare Ashiya Nasaruddin     6.61   6.610000     9.14
# 3      4          Amrutkar Roshani Suresh     7.20   7.300000     8.90
# 4      5            Attarde Komal Bhagwan     7.05   7.450000     9.05
# 5      6        Avhad Pushkaraj Laxmikant     0.00   8.000000     7.91
# 6      7           Aware Priti Balkrushna     8.27   8.500000     9.68
# 7      8               Barse Rutuja Kiran     8.68   9.000000     9.59
# 8      9          Baviskar Pratham Pravin     7.64   7.640000     9.18
# 9     10            Bhalerao Tejal Pradip     9.09   9.360000     9.91
# 10    11            Borse Sharvari Rajesh     7.45   7.910000     9.41
# 11    12  Charak Mehul Singh Bharat Singh     9.00   9.500000     9.77
# 12    13     Chaudhari Hrishikesh Subhash     9.00   9.270000     9.77
# 13    14             Chavan Janhavi Gokul     7.59   7.950000     9.05
# 14    15           Chavan Shraddha Rajesh     6.36   6.590000     8.50
# 15    16             Chavhan Divya Bhikan     8.04   9.346491     9.59
# 16    17              Danej Sakshi Ganesh     8.68   8.770000     9.68
# 17    18              Dasnur Tejas Valmik     8.71   8.910000     9.86
# 18    19              Deore Atharva Mohan     6.25   6.890000      NaN
# 19    20           Deore Mrunal Yashavant     8.32   9.000000     9.55
# 20    21           Desai Pruthvij Prakash     9.09   9.400000     9.64
# 21    22        Deshpande Ojas Shailendra     7.80   8.140000     9.50
# 22    23             Dixit Kedar Rajendra     8.82   9.230000     9.82
# 23    24             Gangurde Dipak Dilip     8.68   9.420000     9.86
# 24    25         Gite Pratiksha Balasaheb     9.42   9.550000     9.05
# 25    26          Hengade Abhishek Yogesh     7.14   7.140000     9.30
# 26    27                Jaju Gauri Jayesh     8.81   9.180000     8.86
# 27    28          Jambhulkar Sweta Rajesh     7.31   8.380000     9.36
# 28    29              Jangam Pranav Suraj     7.00   7.660000     8.60
# 29    30       Kaklij Pratiksha Dadasaheb     8.87   8.770000     9.44
# 30    31              Kale Ashwini Sanjay     8.95   9.160000     9.59
# 31    32              Kapse Chaitali Arun     9.13   9.360000     9.86
# 32    33            Khairnar Tejas Dadaji    95.00  95.000000     9.40
# 33    34           Khatale Ritesh Navnath     9.02   9.200000     9.30
# 34    35               Khond Ameya Satish     8.80   9.160000     9.50
# 35    36      Kodmelwar Koustubh Rajendra     8.50   8.750000     9.64
# 36    37           Kulkarni Rugved Manish     7.60   7.800000     9.75
# 37    38              Kulkarni Soham Arun     8.66   8.660000     9.66
# 38    39                 Kuwar Raj Eknath     6.63   6.820000     9.23
# 39    40             Mahale Shreya Sanjay     0.00   0.000000     9.86
# 40    41               More Siddhi Sudhir     0.00   0.000000     9.59
# 41    42             Mulay Shreyas Nilesh     7.54   7.860000     9.23
# 42    43              Nerkar Mansi Dinesh     8.25   8.800000     9.00
# 43    44             Nimase Aditya Sachin     8.10   8.100000     9.50
# 44    45           Pagar Ashartha Santosh     7.90   8.340000     9.70
# 45    46                 Patel Jaid Aslam     0.00   9.346491     8.50
# 46    47               Patel Janvi Satish     8.95   9.100000     9.67
# 47    48              Patil Archit Dinesh     7.25   7.510000     8.68
# 48    49             Patil Jayesh Prakash     7.40   8.000000     9.50
# 49    50                   Patil Om Nitin     0.00   0.000000     8.30
# 50    51        Patil Priyanka Lalitkumar     8.98   9.450000     9.61
# 51    52               Patil Vedant Vijay     8.61   9.250000     9.21
# 52    53           Patole Tanisha Prakash     4.00   8.000000     9.00
# 53    54             Pawar Devshree Kiran     8.90   9.100000     9.20
# 54    55           Pawar Dhanshree Deepak     7.13   6.600000     9.04
# 55    56            Pawar Manish Sahebrao     8.55   8.640000     9.73
# 56    57              Phadol Purva Gorakh     7.27   7.830000     9.55
# 57    58        Rabade Vishal Chandrasing     9.54  10.000000     9.45
# 58    59            Ratnaparkhi Raj Ashok     8.59   9.346491     9.63
# 59    60             Ravte Rohit Ukhardya     0.00   0.000000     5.00
#
#     Bemarks
# 0      9.90
# 1      9.82
# 2      9.14
# 3       NaN
# 4      9.40
# 5      7.84
# 6      9.14
# 7      9.66
# 8      9.39
# 9      9.95
# 10     9.41
# 11     9.86
# 12     9.33
# 13     9.66
# 14     8.59
# 15     9.66
# 16     9.82
# 17     9.84
# 18     7.20
# 19     9.48
# 20     9.64
# 21     9.71
# 22     9.82
# 23     9.82
# 24     9.18
# 25     9.05
# 26     9.09
# 27     9.00
# 28     8.91
# 29     9.66
# 30     9.89
# 31     9.78
# 32     9.90
# 33     9.45
# 34     9.90
# 35     9.61
# 36    10.00
# 37     9.66
# 38     9.23
# 39     9.91
# 40     9.59
# 41     9.45
# 42     9.25
# 43     9.70
# 44     9.70
# 45     9.14
# 46     9.00
# 47     8.98
# 48     9.10
# 49     8.50
# 50     9.61
# 51     9.40
# 52      NaN
# 53     9.20
# 54     9.45
# 55     9.80
# 56     9.13
# 57     9.54
# 58     9.56
# 59     9.36

# %%
#The fillna() method replaces the NULL values with a specified value (here replace with 'Missing').
df['Temarks']=df['Temarks'].fillna('Missing')
df
# Out:
#     Roll                             Name  Femarks    SEMarks  Temarks  \
# 0      1              Aage Raksha Gajanan     8.40   8.600000      9.8
# 1      2               Ahire Anuja Sanjay     8.14   8.140000     9.32
# 2      3          Ajare Ashiya Nasaruddin     6.61   6.610000     9.14
# 3      4          Amrutkar Roshani Suresh     7.20   7.300000      8.9
# 4      5            Attarde Komal Bhagwan     7.05   7.450000     9.05
# 5      6        Avhad Pushkaraj Laxmikant     0.00   8.000000     7.91
# 6      7           Aware Priti Balkrushna     8.27   8.500000     9.68
# 7      8               Barse Rutuja Kiran     8.68   9.000000     9.59
# 8      9          Baviskar Pratham Pravin     7.64   7.640000     9.18
# 9     10            Bhalerao Tejal Pradip     9.09   9.360000     9.91
# 10    11            Borse Sharvari Rajesh     7.45   7.910000     9.41
# 11    12  Charak Mehul Singh Bharat Singh     9.00   9.500000     9.77
# 12    13     Chaudhari Hrishikesh Subhash     9.00   9.270000     9.77
# 13    14             Chavan Janhavi Gokul     7.59   7.950000     9.05
# 14    15           Chavan Shraddha Rajesh     6.36   6.590000      8.5
# 15    16             Chavhan Divya Bhikan     8.04   9.346491     9.59
# 16    17              Danej Sakshi Ganesh     8.68   8.770000     9.68
# 17    18              Dasnur Tejas Valmik     8.71   8.910000     9.86
# 18    19              Deore Atharva Mohan     6.25   6.890000  Missing
# 19    20           Deore Mrunal Yashavant     8.32   9.000000     9.55
# 20    21           Desai Pruthvij Prakash     9.09   9.400000     9.64
# 21    22        Deshpande Ojas Shailendra     7.80   8.140000      9.5
# 22    23             Dixit Kedar Rajendra     8.82   9.230000     9.82
# 23    24             Gangurde Dipak Dilip     8.68   9.420000     9.86
# 24    25         Gite Pratiksha Balasaheb     9.42   9.550000     9.05
# 25    26          Hengade Abhishek Yogesh     7.14   7.140000      9.3
# 26    27                Jaju Gauri Jayesh     8.81   9.180000     8.86
# 27    28          Jambhulkar Sweta Rajesh     7.31   8.380000     9.36
# 28    29              Jangam Pranav Suraj     7.00   7.660000      8.6
# 29    30       Kaklij Pratiksha Dadasaheb     8.87   8.770000     9.44
# 30    31              Kale Ashwini Sanjay     8.95   9.160000     9.59
# 31    32              Kapse Chaitali Arun     9.13   9.360000     9.86
# 32    33            Khairnar Tejas Dadaji    95.00  95.000000      9.4
# 33    34           Khatale Ritesh Navnath     9.02   9.200000      9.3
# 34    35               Khond Ameya Satish     8.80   9.160000      9.5
# 35    36      Kodmelwar Koustubh Rajendra     8.50   8.750000     9.64
# 36    37           Kulkarni Rugved Manish     7.60   7.800000     9.75
# 37    38              Kulkarni Soham Arun     8.66   8.660000     9.66
# 38    39                 Kuwar Raj Eknath     6.63   6.820000     9.23
# 39    40             Mahale Shreya Sanjay     0.00   0.000000     9.86
# 40    41               More Siddhi Sudhir     0.00   0.000000     9.59
# 41    42             Mulay Shreyas Nilesh     7.54   7.860000     9.23
# 42    43              Nerkar Mansi Dinesh     8.25   8.800000      9.0
# 43    44             Nimase Aditya Sachin     8.10   8.100000      9.5
# 44    45           Pagar Ashartha Santosh     7.90   8.340000      9.7
# 45    46                 Patel Jaid Aslam     0.00   9.346491      8.5
# 46    47               Patel Janvi Satish     8.95   9.100000     9.67
# 47    48              Patil Archit Dinesh     7.25   7.510000     8.68
# 48    49             Patil Jayesh Prakash     7.40   8.000000      9.5
# 49    50                   Patil Om Nitin     0.00   0.000000      8.3
# 50    51        Patil Priyanka Lalitkumar     8.98   9.450000     9.61
# 51    52               Patil Vedant Vijay     8.61   9.250000     9.21
# 52    53           Patole Tanisha Prakash     4.00   8.000000      9.0
# 53    54             Pawar Devshree Kiran     8.90   9.100000      9.2
# 54    55           Pawar Dhanshree Deepak     7.13   6.600000     9.04
# 55    56            Pawar Manish Sahebrao     8.55   8.640000     9.73
# 56    57              Phadol Purva Gorakh     7.27   7.830000     9.55
# 57    58        Rabade Vishal Chandrasing     9.54  10.000000     9.45
# 58    59            Ratnaparkhi Raj Ashok     8.59   9.346491     9.63
# 59    60             Ravte Rohit Ukhardya     0.00   0.000000      5.0
#
#     Bemarks
# 0      9.90
# 1      9.82
# 2      9.14
# 3       NaN
# 4      9.40
# 5      7.84
# 6      9.14
# 7      9.66
# 8      9.39
# 9      9.95
# 10     9.41
# 11     9.86
# 12     9.33
# 13     9.66
# 14     8.59
# 15     9.66
# 16     9.82
# 17     9.84
# 18     7.20
# 19     9.48
# 20     9.64
# 21     9.71
# 22     9.82
# 23     9.82
# 24     9.18
# 25     9.05
# 26     9.09
# 27     9.00
# 28     8.91
# 29     9.66
# 30     9.89
# 31     9.78
# 32     9.90
# 33     9.45
# 34     9.90
# 35     9.61
# 36    10.00
# 37     9.66
# 38     9.23
# 39     9.91
# 40     9.59
# 41     9.45
# 42     9.25
# 43     9.70
# 44     9.70
# 45     9.14
# 46     9.00
# 47     8.98
# 48     9.10
# 49     8.50
# 50     9.61
# 51     9.40
# 52      NaN
# 53     9.20
# 54     9.45
# 55     9.80
# 56     9.13
# 57     9.54
# 58     9.56
# 59     9.36

# %%
#dropping rows having missing value
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Roll       0
# Name       0
# Femarks    0
# SEMarks    0
# Temarks    0
# Bemarks    0
# dtype: int64

# %% [markdown]
# 3. Identify outliers using boxplot and scatterplot.

# %% [markdown]
# If there are outliers, use any of the suitable techniques to deal with them. Apply data transformations on at least one of the variables.
# Box plot / IQR
# Scatter plot
# Z score

# %% [markdown]
# 1. Boxplot/ IQR

# %%
#drawing boxplot for Femarks
sns.boxplot(x=df['Femarks'])
# Out:
# <Axes: xlabel='Femarks'>

# %%
#calculating q1,q2,IQR, lowerbouundry and upperboundry
q1 = df['Femarks'].quantile(0.25)
q3 = df['Femarks'].quantile(0.75)
iqr = q3 - q1    #Interquartile range
lower_boundary = q1 - (1.5*iqr)
upper_boundary = q3 + (1.5*iqr)
print("IQR", iqr, "Lower and upper boundry ",lower_boundary,upper_boundary )
# Out:
# IQR 1.5625000000000009 Lower and upper boundry  4.911249999999999 11.161250000000003

# %%
outliers = df[(df['Femarks'] < lower_boundary) | (df['Femarks'] > upper_boundary)]
outliers
# Out:
#     Roll                       Name  Femarks    SEMarks Temarks  Bemarks
# 5      6  Avhad Pushkaraj Laxmikant      0.0   8.000000    7.91     7.84
# 32    33      Khairnar Tejas Dadaji     95.0  95.000000     9.4     9.90
# 39    40       Mahale Shreya Sanjay      0.0   0.000000    9.86     9.91
# 40    41         More Siddhi Sudhir      0.0   0.000000    9.59     9.59
# 45    46           Patel Jaid Aslam      0.0   9.346491     8.5     9.14
# 49    50             Patil Om Nitin      0.0   0.000000     8.3     8.50
# 59    60       Ravte Rohit Ukhardya      0.0   0.000000     5.0     9.36

# %%
# drop rows containing outliers
df = df.drop(outliers.index)
df
# Out:
#     Roll                             Name  Femarks    SEMarks  Temarks  \
# 0      1              Aage Raksha Gajanan     8.40   8.600000      9.8
# 1      2               Ahire Anuja Sanjay     8.14   8.140000     9.32
# 2      3          Ajare Ashiya Nasaruddin     6.61   6.610000     9.14
# 4      5            Attarde Komal Bhagwan     7.05   7.450000     9.05
# 6      7           Aware Priti Balkrushna     8.27   8.500000     9.68
# 7      8               Barse Rutuja Kiran     8.68   9.000000     9.59
# 8      9          Baviskar Pratham Pravin     7.64   7.640000     9.18
# 9     10            Bhalerao Tejal Pradip     9.09   9.360000     9.91
# 10    11            Borse Sharvari Rajesh     7.45   7.910000     9.41
# 11    12  Charak Mehul Singh Bharat Singh     9.00   9.500000     9.77
# 12    13     Chaudhari Hrishikesh Subhash     9.00   9.270000     9.77
# 13    14             Chavan Janhavi Gokul     7.59   7.950000     9.05
# 14    15           Chavan Shraddha Rajesh     6.36   6.590000      8.5
# 15    16             Chavhan Divya Bhikan     8.04   9.346491     9.59
# 16    17              Danej Sakshi Ganesh     8.68   8.770000     9.68
# 17    18              Dasnur Tejas Valmik     8.71   8.910000     9.86
# 18    19              Deore Atharva Mohan     6.25   6.890000  Missing
# 19    20           Deore Mrunal Yashavant     8.32   9.000000     9.55
# 20    21           Desai Pruthvij Prakash     9.09   9.400000     9.64
# 21    22        Deshpande Ojas Shailendra     7.80   8.140000      9.5
# 22    23             Dixit Kedar Rajendra     8.82   9.230000     9.82
# 23    24             Gangurde Dipak Dilip     8.68   9.420000     9.86
# 24    25         Gite Pratiksha Balasaheb     9.42   9.550000     9.05
# 25    26          Hengade Abhishek Yogesh     7.14   7.140000      9.3
# 26    27                Jaju Gauri Jayesh     8.81   9.180000     8.86
# 27    28          Jambhulkar Sweta Rajesh     7.31   8.380000     9.36
# 28    29              Jangam Pranav Suraj     7.00   7.660000      8.6
# 29    30       Kaklij Pratiksha Dadasaheb     8.87   8.770000     9.44
# 30    31              Kale Ashwini Sanjay     8.95   9.160000     9.59
# 31    32              Kapse Chaitali Arun     9.13   9.360000     9.86
# 33    34           Khatale Ritesh Navnath     9.02   9.200000      9.3
# 34    35               Khond Ameya Satish     8.80   9.160000      9.5
# 35    36      Kodmelwar Koustubh Rajendra     8.50   8.750000     9.64
# 36    37           Kulkarni Rugved Manish     7.60   7.800000     9.75
# 37    38              Kulkarni Soham Arun     8.66   8.660000     9.66
# 38    39                 Kuwar Raj Eknath     6.63   6.820000     9.23
# 41    42             Mulay Shreyas Nilesh     7.54   7.860000     9.23
# 42    43              Nerkar Mansi Dinesh     8.25   8.800000      9.0
# 43    44             Nimase Aditya Sachin     8.10   8.100000      9.5
# 44    45           Pagar Ashartha Santosh     7.90   8.340000      9.7
# 46    47               Patel Janvi Satish     8.95   9.100000     9.67
# 47    48              Patil Archit Dinesh     7.25   7.510000     8.68
# 48    49             Patil Jayesh Prakash     7.40   8.000000      9.5
# 50    51        Patil Priyanka Lalitkumar     8.98   9.450000     9.61
# 51    52               Patil Vedant Vijay     8.61   9.250000     9.21
# 53    54             Pawar Devshree Kiran     8.90   9.100000      9.2
# 54    55           Pawar Dhanshree Deepak     7.13   6.600000     9.04
# 55    56            Pawar Manish Sahebrao     8.55   8.640000     9.73
# 56    57              Phadol Purva Gorakh     7.27   7.830000     9.55
# 57    58        Rabade Vishal Chandrasing     9.54  10.000000     9.45
# 58    59            Ratnaparkhi Raj Ashok     8.59   9.346491     9.63
#
#     Bemarks
# 0      9.90
# 1      9.82
# 2      9.14
# 4      9.40
# 6      9.14
# 7      9.66
# 8      9.39
# 9      9.95
# 10     9.41
# 11     9.86
# 12     9.33
# 13     9.66
# 14     8.59
# 15     9.66
# 16     9.82
# 17     9.84
# 18     7.20
# 19     9.48
# 20     9.64
# 21     9.71
# 22     9.82
# 23     9.82
# 24     9.18
# 25     9.05
# 26     9.09
# 27     9.00
# 28     8.91
# 29     9.66
# 30     9.89
# 31     9.78
# 33     9.45
# 34     9.90
# 35     9.61
# 36    10.00
# 37     9.66
# 38     9.23
# 41     9.45
# 42     9.25
# 43     9.70
# 44     9.70
# 46     9.00
# 47     8.98
# 48     9.10
# 50     9.61
# 51     9.40
# 53     9.20
# 54     9.45
# 55     9.80
# 56     9.13
# 57     9.54
# 58     9.56

# %%
df.reindex(df.index)
# Out:
#     Roll                             Name  Femarks    SEMarks  Temarks  \
# 0      1              Aage Raksha Gajanan     8.40   8.600000      9.8
# 1      2               Ahire Anuja Sanjay     8.14   8.140000     9.32
# 2      3          Ajare Ashiya Nasaruddin     6.61   6.610000     9.14
# 4      5            Attarde Komal Bhagwan     7.05   7.450000     9.05
# 6      7           Aware Priti Balkrushna     8.27   8.500000     9.68
# 7      8               Barse Rutuja Kiran     8.68   9.000000     9.59
# 8      9          Baviskar Pratham Pravin     7.64   7.640000     9.18
# 9     10            Bhalerao Tejal Pradip     9.09   9.360000     9.91
# 10    11            Borse Sharvari Rajesh     7.45   7.910000     9.41
# 11    12  Charak Mehul Singh Bharat Singh     9.00   9.500000     9.77
# 12    13     Chaudhari Hrishikesh Subhash     9.00   9.270000     9.77
# 13    14             Chavan Janhavi Gokul     7.59   7.950000     9.05
# 14    15           Chavan Shraddha Rajesh     6.36   6.590000      8.5
# 15    16             Chavhan Divya Bhikan     8.04   9.346491     9.59
# 16    17              Danej Sakshi Ganesh     8.68   8.770000     9.68
# 17    18              Dasnur Tejas Valmik     8.71   8.910000     9.86
# 18    19              Deore Atharva Mohan     6.25   6.890000  Missing
# 19    20           Deore Mrunal Yashavant     8.32   9.000000     9.55
# 20    21           Desai Pruthvij Prakash     9.09   9.400000     9.64
# 21    22        Deshpande Ojas Shailendra     7.80   8.140000      9.5
# 22    23             Dixit Kedar Rajendra     8.82   9.230000     9.82
# 23    24             Gangurde Dipak Dilip     8.68   9.420000     9.86
# 24    25         Gite Pratiksha Balasaheb     9.42   9.550000     9.05
# 25    26          Hengade Abhishek Yogesh     7.14   7.140000      9.3
# 26    27                Jaju Gauri Jayesh     8.81   9.180000     8.86
# 27    28          Jambhulkar Sweta Rajesh     7.31   8.380000     9.36
# 28    29              Jangam Pranav Suraj     7.00   7.660000      8.6
# 29    30       Kaklij Pratiksha Dadasaheb     8.87   8.770000     9.44
# 30    31              Kale Ashwini Sanjay     8.95   9.160000     9.59
# 31    32              Kapse Chaitali Arun     9.13   9.360000     9.86
# 33    34           Khatale Ritesh Navnath     9.02   9.200000      9.3
# 34    35               Khond Ameya Satish     8.80   9.160000      9.5
# 35    36      Kodmelwar Koustubh Rajendra     8.50   8.750000     9.64
# 36    37           Kulkarni Rugved Manish     7.60   7.800000     9.75
# 37    38              Kulkarni Soham Arun     8.66   8.660000     9.66
# 38    39                 Kuwar Raj Eknath     6.63   6.820000     9.23
# 41    42             Mulay Shreyas Nilesh     7.54   7.860000     9.23
# 42    43              Nerkar Mansi Dinesh     8.25   8.800000      9.0
# 43    44             Nimase Aditya Sachin     8.10   8.100000      9.5
# 44    45           Pagar Ashartha Santosh     7.90   8.340000      9.7
# 46    47               Patel Janvi Satish     8.95   9.100000     9.67
# 47    48              Patil Archit Dinesh     7.25   7.510000     8.68
# 48    49             Patil Jayesh Prakash     7.40   8.000000      9.5
# 50    51        Patil Priyanka Lalitkumar     8.98   9.450000     9.61
# 51    52               Patil Vedant Vijay     8.61   9.250000     9.21
# 53    54             Pawar Devshree Kiran     8.90   9.100000      9.2
# 54    55           Pawar Dhanshree Deepak     7.13   6.600000     9.04
# 55    56            Pawar Manish Sahebrao     8.55   8.640000     9.73
# 56    57              Phadol Purva Gorakh     7.27   7.830000     9.55
# 57    58        Rabade Vishal Chandrasing     9.54  10.000000     9.45
# 58    59            Ratnaparkhi Raj Ashok     8.59   9.346491     9.63
#
#     Bemarks
# 0      9.90
# 1      9.82
# 2      9.14
# 4      9.40
# 6      9.14
# 7      9.66
# 8      9.39
# 9      9.95
# 10     9.41
# 11     9.86
# 12     9.33
# 13     9.66
# 14     8.59
# 15     9.66
# 16     9.82
# 17     9.84
# 18     7.20
# 19     9.48
# 20     9.64
# 21     9.71
# 22     9.82
# 23     9.82
# 24     9.18
# 25     9.05
# 26     9.09
# 27     9.00
# 28     8.91
# 29     9.66
# 30     9.89
# 31     9.78
# 33     9.45
# 34     9.90
# 35     9.61
# 36    10.00
# 37     9.66
# 38     9.23
# 41     9.45
# 42     9.25
# 43     9.70
# 44     9.70
# 46     9.00
# 47     8.98
# 48     9.10
# 50     9.61
# 51     9.40
# 53     9.20
# 54     9.45
# 55     9.80
# 56     9.13
# 57     9.54
# 58     9.56

# %%
sns.boxplot(x=df['Femarks'])
# Out:
# <Axes: xlabel='Femarks'>

# %% [markdown]
# 4. Handle outlier using any technique.

# %%
# change vale to create outliers
df.at[7,"SEMarks"]=20
df
# Out:
#     Roll                             Name  Femarks    SEMarks  Temarks  \
# 0      1              Aage Raksha Gajanan     8.40   8.600000      9.8
# 1      2               Ahire Anuja Sanjay     8.14   8.140000     9.32
# 2      3          Ajare Ashiya Nasaruddin     6.61   6.610000     9.14
# 4      5            Attarde Komal Bhagwan     7.05   7.450000     9.05
# 6      7           Aware Priti Balkrushna     8.27   8.500000     9.68
# 7      8               Barse Rutuja Kiran     8.68  20.000000     9.59
# 8      9          Baviskar Pratham Pravin     7.64   7.640000     9.18
# 9     10            Bhalerao Tejal Pradip     9.09   9.360000     9.91
# 10    11            Borse Sharvari Rajesh     7.45   7.910000     9.41
# 11    12  Charak Mehul Singh Bharat Singh     9.00   9.500000     9.77
# 12    13     Chaudhari Hrishikesh Subhash     9.00   9.270000     9.77
# 13    14             Chavan Janhavi Gokul     7.59   7.950000     9.05
# 14    15           Chavan Shraddha Rajesh     6.36   6.590000      8.5
# 15    16             Chavhan Divya Bhikan     8.04   9.346491     9.59
# 16    17              Danej Sakshi Ganesh     8.68   8.770000     9.68
# 17    18              Dasnur Tejas Valmik     8.71   8.910000     9.86
# 18    19              Deore Atharva Mohan     6.25   6.890000  Missing
# 19    20           Deore Mrunal Yashavant     8.32   9.000000     9.55
# 20    21           Desai Pruthvij Prakash     9.09   9.400000     9.64
# 21    22        Deshpande Ojas Shailendra     7.80   8.140000      9.5
# 22    23             Dixit Kedar Rajendra     8.82   9.230000     9.82
# 23    24             Gangurde Dipak Dilip     8.68   9.420000     9.86
# 24    25         Gite Pratiksha Balasaheb     9.42   9.550000     9.05
# 25    26          Hengade Abhishek Yogesh     7.14   7.140000      9.3
# 26    27                Jaju Gauri Jayesh     8.81   9.180000     8.86
# 27    28          Jambhulkar Sweta Rajesh     7.31   8.380000     9.36
# 28    29              Jangam Pranav Suraj     7.00   7.660000      8.6
# 29    30       Kaklij Pratiksha Dadasaheb     8.87   8.770000     9.44
# 30    31              Kale Ashwini Sanjay     8.95   9.160000     9.59
# 31    32              Kapse Chaitali Arun     9.13   9.360000     9.86
# 33    34           Khatale Ritesh Navnath     9.02   9.200000      9.3
# 34    35               Khond Ameya Satish     8.80   9.160000      9.5
# 35    36      Kodmelwar Koustubh Rajendra     8.50   8.750000     9.64
# 36    37           Kulkarni Rugved Manish     7.60   7.800000     9.75
# 37    38              Kulkarni Soham Arun     8.66   8.660000     9.66
# 38    39                 Kuwar Raj Eknath     6.63   6.820000     9.23
# 41    42             Mulay Shreyas Nilesh     7.54   7.860000     9.23
# 42    43              Nerkar Mansi Dinesh     8.25   8.800000      9.0
# 43    44             Nimase Aditya Sachin     8.10   8.100000      9.5
# 44    45           Pagar Ashartha Santosh     7.90   8.340000      9.7
# 46    47               Patel Janvi Satish     8.95   9.100000     9.67
# 47    48              Patil Archit Dinesh     7.25   7.510000     8.68
# 48    49             Patil Jayesh Prakash     7.40   8.000000      9.5
# 50    51        Patil Priyanka Lalitkumar     8.98   9.450000     9.61
# 51    52               Patil Vedant Vijay     8.61   9.250000     9.21
# 53    54             Pawar Devshree Kiran     8.90   9.100000      9.2
# 54    55           Pawar Dhanshree Deepak     7.13   6.600000     9.04
# 55    56            Pawar Manish Sahebrao     8.55   8.640000     9.73
# 56    57              Phadol Purva Gorakh     7.27   7.830000     9.55
# 57    58        Rabade Vishal Chandrasing     9.54  10.000000     9.45
# 58    59            Ratnaparkhi Raj Ashok     8.59   9.346491     9.63
#
#     Bemarks
# 0      9.90
# 1      9.82
# 2      9.14
# 4      9.40
# 6      9.14
# 7      9.66
# 8      9.39
# 9      9.95
# 10     9.41
# 11     9.86
# 12     9.33
# 13     9.66
# 14     8.59
# 15     9.66
# 16     9.82
# 17     9.84
# 18     7.20
# 19     9.48
# 20     9.64
# 21     9.71
# 22     9.82
# 23     9.82
# 24     9.18
# 25     9.05
# 26     9.09
# 27     9.00
# 28     8.91
# 29     9.66
# 30     9.89
# 31     9.78
# 33     9.45
# 34     9.90
# 35     9.61
# 36    10.00
# 37     9.66
# 38     9.23
# 41     9.45
# 42     9.25
# 43     9.70
# 44     9.70
# 46     9.00
# 47     8.98
# 48     9.10
# 50     9.61
# 51     9.40
# 53     9.20
# 54     9.45
# 55     9.80
# 56     9.13
# 57     9.54
# 58     9.56

# %% [markdown]
# 2. Scatter Plot

# %%
sns.scatterplot(x='Femarks', y='SEMarks', data=df)
# Out:
# <Axes: xlabel='Femarks', ylabel='SEMarks'>

# %%
#draw a scatter plot for finding outlier
fig, ax = plt.subplots(figsize=(6, 4))
ax.scatter(df['Femarks'], df['SEMarks'])
ax.set_xlabel('(Femarks )')
ax.set_ylabel('(SEMarks )')
plt.show()

# %%
sem2outliers = df[(df['SEMarks'] > 15)]
sem2outliers
# Out:
#    Roll                Name  Femarks  SEMarks Temarks  Bemarks
# 7     8  Barse Rutuja Kiran     8.68     20.0    9.59     9.66

# %%
# Finding the mean of the column having NaN
median_value = df['SEMarks'].median()
print(median_value)
# Out:
# 8.75

# %%
#insert outlier with median value
df.at[7,'SEMarks']=median_value

# %%
#draw a scatter plot to check  outlier removal
fig, ax = plt.subplots(figsize=(6, 4))
ax.scatter(df['Femarks'], df['SEMarks'])
ax.set_xlabel('(Femarks )')
ax.set_ylabel('(SEMarks )')
plt.show()

# %% [markdown]
# 3. Z-Score

# %%
df.at[2,'Femarks']=200
df
# Out:
#     Roll                             Name  Femarks    SEMarks  Temarks  \
# 0      1              Aage Raksha Gajanan     8.40   8.600000      9.8
# 1      2               Ahire Anuja Sanjay     8.14   8.140000     9.32
# 2      3          Ajare Ashiya Nasaruddin   200.00   6.610000     9.14
# 4      5            Attarde Komal Bhagwan     7.05   7.450000     9.05
# 6      7           Aware Priti Balkrushna     8.27   8.500000     9.68
# 7      8               Barse Rutuja Kiran     8.68   8.750000     9.59
# 8      9          Baviskar Pratham Pravin     7.64   7.640000     9.18
# 9     10            Bhalerao Tejal Pradip     9.09   9.360000     9.91
# 10    11            Borse Sharvari Rajesh     7.45   7.910000     9.41
# 11    12  Charak Mehul Singh Bharat Singh     9.00   9.500000     9.77
# 12    13     Chaudhari Hrishikesh Subhash     9.00   9.270000     9.77
# 13    14             Chavan Janhavi Gokul     7.59   7.950000     9.05
# 14    15           Chavan Shraddha Rajesh     6.36   6.590000      8.5
# 15    16             Chavhan Divya Bhikan     8.04   9.346491     9.59
# 16    17              Danej Sakshi Ganesh     8.68   8.770000     9.68
# 17    18              Dasnur Tejas Valmik     8.71   8.910000     9.86
# 18    19              Deore Atharva Mohan     6.25   6.890000  Missing
# 19    20           Deore Mrunal Yashavant     8.32   9.000000     9.55
# 20    21           Desai Pruthvij Prakash     9.09   9.400000     9.64
# 21    22        Deshpande Ojas Shailendra     7.80   8.140000      9.5
# 22    23             Dixit Kedar Rajendra     8.82   9.230000     9.82
# 23    24             Gangurde Dipak Dilip     8.68   9.420000     9.86
# 24    25         Gite Pratiksha Balasaheb     9.42   9.550000     9.05
# 25    26          Hengade Abhishek Yogesh     7.14   7.140000      9.3
# 26    27                Jaju Gauri Jayesh     8.81   9.180000     8.86
# 27    28          Jambhulkar Sweta Rajesh     7.31   8.380000     9.36
# 28    29              Jangam Pranav Suraj     7.00   7.660000      8.6
# 29    30       Kaklij Pratiksha Dadasaheb     8.87   8.770000     9.44
# 30    31              Kale Ashwini Sanjay     8.95   9.160000     9.59
# 31    32              Kapse Chaitali Arun     9.13   9.360000     9.86
# 33    34           Khatale Ritesh Navnath     9.02   9.200000      9.3
# 34    35               Khond Ameya Satish     8.80   9.160000      9.5
# 35    36      Kodmelwar Koustubh Rajendra     8.50   8.750000     9.64
# 36    37           Kulkarni Rugved Manish     7.60   7.800000     9.75
# 37    38              Kulkarni Soham Arun     8.66   8.660000     9.66
# 38    39                 Kuwar Raj Eknath     6.63   6.820000     9.23
# 41    42             Mulay Shreyas Nilesh     7.54   7.860000     9.23
# 42    43              Nerkar Mansi Dinesh     8.25   8.800000      9.0
# 43    44             Nimase Aditya Sachin     8.10   8.100000      9.5
# 44    45           Pagar Ashartha Santosh     7.90   8.340000      9.7
# 46    47               Patel Janvi Satish     8.95   9.100000     9.67
# 47    48              Patil Archit Dinesh     7.25   7.510000     8.68
# 48    49             Patil Jayesh Prakash     7.40   8.000000      9.5
# 50    51        Patil Priyanka Lalitkumar     8.98   9.450000     9.61
# 51    52               Patil Vedant Vijay     8.61   9.250000     9.21
# 53    54             Pawar Devshree Kiran     8.90   9.100000      9.2
# 54    55           Pawar Dhanshree Deepak     7.13   6.600000     9.04
# 55    56            Pawar Manish Sahebrao     8.55   8.640000     9.73
# 56    57              Phadol Purva Gorakh     7.27   7.830000     9.55
# 57    58        Rabade Vishal Chandrasing     9.54  10.000000     9.45
# 58    59            Ratnaparkhi Raj Ashok     8.59   9.346491     9.63
#
#     Bemarks
# 0      9.90
# 1      9.82
# 2      9.14
# 4      9.40
# 6      9.14
# 7      9.66
# 8      9.39
# 9      9.95
# 10     9.41
# 11     9.86
# 12     9.33
# 13     9.66
# 14     8.59
# 15     9.66
# 16     9.82
# 17     9.84
# 18     7.20
# 19     9.48
# 20     9.64
# 21     9.71
# 22     9.82
# 23     9.82
# 24     9.18
# 25     9.05
# 26     9.09
# 27     9.00
# 28     8.91
# 29     9.66
# 30     9.89
# 31     9.78
# 33     9.45
# 34     9.90
# 35     9.61
# 36    10.00
# 37     9.66
# 38     9.23
# 41     9.45
# 42     9.25
# 43     9.70
# 44     9.70
# 46     9.00
# 47     8.98
# 48     9.10
# 50     9.61
# 51     9.40
# 53     9.20
# 54     9.45
# 55     9.80
# 56     9.13
# 57     9.54
# 58     9.56

# %%
#insert outlier with
df.at[2,'Bemarks']=40
df
# Out:
#     Roll                             Name  Femarks    SEMarks  Temarks  \
# 0      1              Aage Raksha Gajanan     8.40   8.600000      9.8
# 1      2               Ahire Anuja Sanjay     8.14   8.140000     9.32
# 2      3          Ajare Ashiya Nasaruddin   200.00   6.610000     9.14
# 4      5            Attarde Komal Bhagwan     7.05   7.450000     9.05
# 6      7           Aware Priti Balkrushna     8.27   8.500000     9.68
# 7      8               Barse Rutuja Kiran     8.68   8.750000     9.59
# 8      9          Baviskar Pratham Pravin     7.64   7.640000     9.18
# 9     10            Bhalerao Tejal Pradip     9.09   9.360000     9.91
# 10    11            Borse Sharvari Rajesh     7.45   7.910000     9.41
# 11    12  Charak Mehul Singh Bharat Singh     9.00   9.500000     9.77
# 12    13     Chaudhari Hrishikesh Subhash     9.00   9.270000     9.77
# 13    14             Chavan Janhavi Gokul     7.59   7.950000     9.05
# 14    15           Chavan Shraddha Rajesh     6.36   6.590000      8.5
# 15    16             Chavhan Divya Bhikan     8.04   9.346491     9.59
# 16    17              Danej Sakshi Ganesh     8.68   8.770000     9.68
# 17    18              Dasnur Tejas Valmik     8.71   8.910000     9.86
# 18    19              Deore Atharva Mohan     6.25   6.890000  Missing
# 19    20           Deore Mrunal Yashavant     8.32   9.000000     9.55
# 20    21           Desai Pruthvij Prakash     9.09   9.400000     9.64
# 21    22        Deshpande Ojas Shailendra     7.80   8.140000      9.5
# 22    23             Dixit Kedar Rajendra     8.82   9.230000     9.82
# 23    24             Gangurde Dipak Dilip     8.68   9.420000     9.86
# 24    25         Gite Pratiksha Balasaheb     9.42   9.550000     9.05
# 25    26          Hengade Abhishek Yogesh     7.14   7.140000      9.3
# 26    27                Jaju Gauri Jayesh     8.81   9.180000     8.86
# 27    28          Jambhulkar Sweta Rajesh     7.31   8.380000     9.36
# 28    29              Jangam Pranav Suraj     7.00   7.660000      8.6
# 29    30       Kaklij Pratiksha Dadasaheb     8.87   8.770000     9.44
# 30    31              Kale Ashwini Sanjay     8.95   9.160000     9.59
# 31    32              Kapse Chaitali Arun     9.13   9.360000     9.86
# 33    34           Khatale Ritesh Navnath     9.02   9.200000      9.3
# 34    35               Khond Ameya Satish     8.80   9.160000      9.5
# 35    36      Kodmelwar Koustubh Rajendra     8.50   8.750000     9.64
# 36    37           Kulkarni Rugved Manish     7.60   7.800000     9.75
# 37    38              Kulkarni Soham Arun     8.66   8.660000     9.66
# 38    39                 Kuwar Raj Eknath     6.63   6.820000     9.23
# 41    42             Mulay Shreyas Nilesh     7.54   7.860000     9.23
# 42    43              Nerkar Mansi Dinesh     8.25   8.800000      9.0
# 43    44             Nimase Aditya Sachin     8.10   8.100000      9.5
# 44    45           Pagar Ashartha Santosh     7.90   8.340000      9.7
# 46    47               Patel Janvi Satish     8.95   9.100000     9.67
# 47    48              Patil Archit Dinesh     7.25   7.510000     8.68
# 48    49             Patil Jayesh Prakash     7.40   8.000000      9.5
# 50    51        Patil Priyanka Lalitkumar     8.98   9.450000     9.61
# 51    52               Patil Vedant Vijay     8.61   9.250000     9.21
# 53    54             Pawar Devshree Kiran     8.90   9.100000      9.2
# 54    55           Pawar Dhanshree Deepak     7.13   6.600000     9.04
# 55    56            Pawar Manish Sahebrao     8.55   8.640000     9.73
# 56    57              Phadol Purva Gorakh     7.27   7.830000     9.55
# 57    58        Rabade Vishal Chandrasing     9.54  10.000000     9.45
# 58    59            Ratnaparkhi Raj Ashok     8.59   9.346491     9.63
#
#     Bemarks
# 0      9.90
# 1      9.82
# 2     40.00
# 4      9.40
# 6      9.14
# 7      9.66
# 8      9.39
# 9      9.95
# 10     9.41
# 11     9.86
# 12     9.33
# 13     9.66
# 14     8.59
# 15     9.66
# 16     9.82
# 17     9.84
# 18     7.20
# 19     9.48
# 20     9.64
# 21     9.71
# 22     9.82
# 23     9.82
# 24     9.18
# 25     9.05
# 26     9.09
# 27     9.00
# 28     8.91
# 29     9.66
# 30     9.89
# 31     9.78
# 33     9.45
# 34     9.90
# 35     9.61
# 36    10.00
# 37     9.66
# 38     9.23
# 41     9.45
# 42     9.25
# 43     9.70
# 44     9.70
# 46     9.00
# 47     8.98
# 48     9.10
# 50     9.61
# 51     9.40
# 53     9.20
# 54     9.45
# 55     9.80
# 56     9.13
# 57     9.54
# 58     9.56

# %%
from scipy import stats
z = np.abs(stats.zscore(df['Bemarks']))
print(z)
# Out:
# 0     0.034429
# 1     0.053209
# 2     7.031418
# 4     0.151802
# 6     0.212836
# 7     0.090768
# 8     0.154150
# 9     0.022692
# 10    0.149455
# 11    0.043819
# 12    0.168234
# 13    0.090768
# 14    0.341946
# 15    0.090768
# 16    0.053209
# 17    0.048514
# 18    0.668243
# 19    0.133023
# 20    0.095463
# 21    0.079031
# 22    0.053209
# 23    0.053209
# 24    0.203446
# 25    0.233963
# 26    0.224573
# 27    0.245701
# 28    0.266828
# 29    0.090768
# 30    0.036777
# 31    0.062599
# 33    0.140065
# 34    0.034429
# 35    0.102506
# 36    0.010955
# 37    0.090768
# 38    0.191709
# 41    0.140065
# 42    0.187014
# 43    0.081379
# 44    0.081379
# 46    0.245701
# 47    0.250395
# 48    0.222226
# 50    0.102506
# 51    0.151802
# 53    0.198751
# 54    0.140065
# 55    0.057904
# 56    0.215184
# 57    0.118938
# 58    0.114243
# Name: Bemarks, dtype: float64

# %%
#removing outlier naving z score > 2
#set a threshold for the z-score, specifying when a data point is considered an outlier. In this case, the threshold is set to 2.
threshold_z = 2
outliers_indices = np.where(z > threshold_z)[0]
outliers_indices
no_outliers = df.drop(outliers_indices)
print("original Dataframe Shape: ", df.shape)
print("Dataframe Shape after Removing Outliers", no_outliers.shape)
no_outliers
# Out:
# original Dataframe Shape:  (51, 6)
# Dataframe Shape after Removing Outliers (50, 6)
#     Roll                             Name  Femarks    SEMarks  Temarks  \
# 0      1              Aage Raksha Gajanan     8.40   8.600000      9.8
# 1      2               Ahire Anuja Sanjay     8.14   8.140000     9.32
# 4      5            Attarde Komal Bhagwan     7.05   7.450000     9.05
# 6      7           Aware Priti Balkrushna     8.27   8.500000     9.68
# 7      8               Barse Rutuja Kiran     8.68   8.750000     9.59
# 8      9          Baviskar Pratham Pravin     7.64   7.640000     9.18
# 9     10            Bhalerao Tejal Pradip     9.09   9.360000     9.91
# 10    11            Borse Sharvari Rajesh     7.45   7.910000     9.41
# 11    12  Charak Mehul Singh Bharat Singh     9.00   9.500000     9.77
# 12    13     Chaudhari Hrishikesh Subhash     9.00   9.270000     9.77
# 13    14             Chavan Janhavi Gokul     7.59   7.950000     9.05
# 14    15           Chavan Shraddha Rajesh     6.36   6.590000      8.5
# 15    16             Chavhan Divya Bhikan     8.04   9.346491     9.59
# 16    17              Danej Sakshi Ganesh     8.68   8.770000     9.68
# 17    18              Dasnur Tejas Valmik     8.71   8.910000     9.86
# 18    19              Deore Atharva Mohan     6.25   6.890000  Missing
# 19    20           Deore Mrunal Yashavant     8.32   9.000000     9.55
# 20    21           Desai Pruthvij Prakash     9.09   9.400000     9.64
# 21    22        Deshpande Ojas Shailendra     7.80   8.140000      9.5
# 22    23             Dixit Kedar Rajendra     8.82   9.230000     9.82
# 23    24             Gangurde Dipak Dilip     8.68   9.420000     9.86
# 24    25         Gite Pratiksha Balasaheb     9.42   9.550000     9.05
# 25    26          Hengade Abhishek Yogesh     7.14   7.140000      9.3
# 26    27                Jaju Gauri Jayesh     8.81   9.180000     8.86
# 27    28          Jambhulkar Sweta Rajesh     7.31   8.380000     9.36
# 28    29              Jangam Pranav Suraj     7.00   7.660000      8.6
# 29    30       Kaklij Pratiksha Dadasaheb     8.87   8.770000     9.44
# 30    31              Kale Ashwini Sanjay     8.95   9.160000     9.59
# 31    32              Kapse Chaitali Arun     9.13   9.360000     9.86
# 33    34           Khatale Ritesh Navnath     9.02   9.200000      9.3
# 34    35               Khond Ameya Satish     8.80   9.160000      9.5
# 35    36      Kodmelwar Koustubh Rajendra     8.50   8.750000     9.64
# 36    37           Kulkarni Rugved Manish     7.60   7.800000     9.75
# 37    38              Kulkarni Soham Arun     8.66   8.660000     9.66
# 38    39                 Kuwar Raj Eknath     6.63   6.820000     9.23
# 41    42             Mulay Shreyas Nilesh     7.54   7.860000     9.23
# 42    43              Nerkar Mansi Dinesh     8.25   8.800000      9.0
# 43    44             Nimase Aditya Sachin     8.10   8.100000      9.5
# 44    45           Pagar Ashartha Santosh     7.90   8.340000      9.7
# 46    47               Patel Janvi Satish     8.95   9.100000     9.67
# 47    48              Patil Archit Dinesh     7.25   7.510000     8.68
# 48    49             Patil Jayesh Prakash     7.40   8.000000      9.5
# 50    51        Patil Priyanka Lalitkumar     8.98   9.450000     9.61
# 51    52               Patil Vedant Vijay     8.61   9.250000     9.21
# 53    54             Pawar Devshree Kiran     8.90   9.100000      9.2
# 54    55           Pawar Dhanshree Deepak     7.13   6.600000     9.04
# 55    56            Pawar Manish Sahebrao     8.55   8.640000     9.73
# 56    57              Phadol Purva Gorakh     7.27   7.830000     9.55
# 57    58        Rabade Vishal Chandrasing     9.54  10.000000     9.45
# 58    59            Ratnaparkhi Raj Ashok     8.59   9.346491     9.63
#
#     Bemarks
# 0      9.90
# 1      9.82
# 4      9.40
# 6      9.14
# 7      9.66
# 8      9.39
# 9      9.95
# 10     9.41
# 11     9.86
# 12     9.33
# 13     9.66
# 14     8.59
# 15     9.66
# 16     9.82
# 17     9.84
# 18     7.20
# 19     9.48
# 20     9.64
# 21     9.71
# 22     9.82
# 23     9.82
# 24     9.18
# 25     9.05
# 26     9.09
# 27     9.00
# 28     8.91
# 29     9.66
# 30     9.89
# 31     9.78
# 33     9.45
# 34     9.90
# 35     9.61
# 36    10.00
# 37     9.66
# 38     9.23
# 41     9.45
# 42     9.25
# 43     9.70
# 44     9.70
# 46     9.00
# 47     8.98
# 48     9.10
# 50     9.61
# 51     9.40
# 53     9.20
# 54     9.45
# 55     9.80
# 56     9.13
# 57     9.54
# 58     9.56

# %% [markdown]
# 5. Perform any 2 data normalization technique.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PowerTransformer

# %%
# Original data distribution
plt.figure(figsize=(15, 10))
plt.subplot(3, 2, 1)
sns.histplot(df['Femarks'], kde=True, color='blue')
plt.title("Original 'FEmarks' Distribution")

plt.subplot(3, 2, 2)
sns.histplot(df['SEMarks'], kde=True, color='orange')
plt.title("Original 'SEmarks' Distribution")

plt.subplots_adjust(hspace=1)

plt.subplot(3, 2, 3)
sns.histplot(df['Bemarks'], kde=True, color='green')
plt.title("Original 'BEmarks' Distribution")
# Out:
# Text(0.5, 1.0, "Original 'BEmarks' Distribution")

# %%
# Min-Max Scaling for 'FEmarks' column
scaler_minmax = MinMaxScaler()
df_minmax = pd.DataFrame(scaler_minmax.fit_transform(df[['Femarks']]), columns=['Femarks'])

# Z-Score Normalization for 'TEmarks' column
scaler_zscore = StandardScaler()
df_zscore = pd.DataFrame(scaler_zscore.fit_transform(df[['SEMarks']]), columns=['SEMarks'])

# Decimal Normalization for 'BEmarks' column
scaler_decimal = PowerTransformer()
df_decimal = pd.DataFrame(scaler_decimal.fit_transform(df[['Bemarks']]), columns=['Bemarks'])

# %%
# Normalized data distribution
plt.figure(figsize=(15, 10))

plt.subplot(3, 2, 1)
sns.histplot(df_minmax['Femarks'], kde=True, color='blue')
plt.title("Min-Max Scaled 'FEmarks' Distribution")

plt.subplot(3, 2, 2)
sns.histplot(df_zscore['SEMarks'], kde=True, color='orange')
plt.title("Z-Score Normalized 'SEmarks' Distribution")

plt.subplot(3, 2, 3)
sns.histplot(df_decimal['Bemarks'], kde=True, color='green')
plt.title("Decimal Normalized 'BEmarks' Distribution")

plt.tight_layout()
plt.show()

# %%
scaler = MinMaxScaler()
df['SE_minmax'] = scaler.fit_transform(df[['SEMarks']])

zscore=StandardScaler()
df['SE_zscore'] = zscore.fit_transform(df[['SEMarks']])

# %%
df
# Out:
#     Roll                             Name  Femarks    SEMarks  Temarks  \
# 0      1              Aage Raksha Gajanan     8.40   8.600000      9.8
# 1      2               Ahire Anuja Sanjay     8.14   8.140000     9.32
# 2      3          Ajare Ashiya Nasaruddin   200.00   6.610000     9.14
# 4      5            Attarde Komal Bhagwan     7.05   7.450000     9.05
# 6      7           Aware Priti Balkrushna     8.27   8.500000     9.68
# 7      8               Barse Rutuja Kiran     8.68   8.750000     9.59
# 8      9          Baviskar Pratham Pravin     7.64   7.640000     9.18
# 9     10            Bhalerao Tejal Pradip     9.09   9.360000     9.91
# 10    11            Borse Sharvari Rajesh     7.45   7.910000     9.41
# 11    12  Charak Mehul Singh Bharat Singh     9.00   9.500000     9.77
# 12    13     Chaudhari Hrishikesh Subhash     9.00   9.270000     9.77
# 13    14             Chavan Janhavi Gokul     7.59   7.950000     9.05
# 14    15           Chavan Shraddha Rajesh     6.36   6.590000      8.5
# 15    16             Chavhan Divya Bhikan     8.04   9.346491     9.59
# 16    17              Danej Sakshi Ganesh     8.68   8.770000     9.68
# 17    18              Dasnur Tejas Valmik     8.71   8.910000     9.86
# 18    19              Deore Atharva Mohan     6.25   6.890000  Missing
# 19    20           Deore Mrunal Yashavant     8.32   9.000000     9.55
# 20    21           Desai Pruthvij Prakash     9.09   9.400000     9.64
# 21    22        Deshpande Ojas Shailendra     7.80   8.140000      9.5
# 22    23             Dixit Kedar Rajendra     8.82   9.230000     9.82
# 23    24             Gangurde Dipak Dilip     8.68   9.420000     9.86
# 24    25         Gite Pratiksha Balasaheb     9.42   9.550000     9.05
# 25    26          Hengade Abhishek Yogesh     7.14   7.140000      9.3
# 26    27                Jaju Gauri Jayesh     8.81   9.180000     8.86
# 27    28          Jambhulkar Sweta Rajesh     7.31   8.380000     9.36
# 28    29              Jangam Pranav Suraj     7.00   7.660000      8.6
# 29    30       Kaklij Pratiksha Dadasaheb     8.87   8.770000     9.44
# 30    31              Kale Ashwini Sanjay     8.95   9.160000     9.59
# 31    32              Kapse Chaitali Arun     9.13   9.360000     9.86
# 33    34           Khatale Ritesh Navnath     9.02   9.200000      9.3
# 34    35               Khond Ameya Satish     8.80   9.160000      9.5
# 35    36      Kodmelwar Koustubh Rajendra     8.50   8.750000     9.64
# 36    37           Kulkarni Rugved Manish     7.60   7.800000     9.75
# 37    38              Kulkarni Soham Arun     8.66   8.660000     9.66
# 38    39                 Kuwar Raj Eknath     6.63   6.820000     9.23
# 41    42             Mulay Shreyas Nilesh     7.54   7.860000     9.23
# 42    43              Nerkar Mansi Dinesh     8.25   8.800000      9.0
# 43    44             Nimase Aditya Sachin     8.10   8.100000      9.5
# 44    45           Pagar Ashartha Santosh     7.90   8.340000      9.7
# 46    47               Patel Janvi Satish     8.95   9.100000     9.67
# 47    48              Patil Archit Dinesh     7.25   7.510000     8.68
# 48    49             Patil Jayesh Prakash     7.40   8.000000      9.5
# 50    51        Patil Priyanka Lalitkumar     8.98   9.450000     9.61
# 51    52               Patil Vedant Vijay     8.61   9.250000     9.21
# 53    54             Pawar Devshree Kiran     8.90   9.100000      9.2
# 54    55           Pawar Dhanshree Deepak     7.13   6.600000     9.04
# 55    56            Pawar Manish Sahebrao     8.55   8.640000     9.73
# 56    57              Phadol Purva Gorakh     7.27   7.830000     9.55
# 57    58        Rabade Vishal Chandrasing     9.54  10.000000     9.45
# 58    59            Ratnaparkhi Raj Ashok     8.59   9.346491     9.63
#
#     Bemarks  SE_minmax  SE_zscore
# 0      9.90   0.589443   0.127617
# 1      9.82   0.454545  -0.396983
# 2     40.00   0.005865  -2.141850
# 4      9.40   0.252199  -1.183884
# 6      9.14   0.560117   0.013574
# 7      9.66   0.633431   0.298683
# 8      9.39   0.307918  -0.967201
# 9      9.95   0.812317   0.994348
# 10     9.41   0.387097  -0.659283
# 11     9.86   0.853372   1.154009
# 12     9.33   0.785924   0.891709
# 13     9.66   0.398827  -0.613666
# 14     8.59   0.000000  -2.164658
# 15     9.66   0.808355   0.978943
# 16     9.82   0.639296   0.321491
# 17     9.84   0.680352   0.481152
# 18     7.20   0.087977  -1.822528
# 19     9.48   0.706745   0.583792
# 20     9.64   0.824047   1.039966
# 21     9.71   0.454545  -0.396983
# 22     9.82   0.774194   0.846092
# 23     9.82   0.829912   1.062775
# 24     9.18   0.868035   1.211031
# 25     9.05   0.161290  -1.537419
# 26     9.09   0.759531   0.789070
# 27     9.00   0.524927  -0.123278
# 28     8.91   0.313783  -0.944392
# 29     9.66   0.639296   0.321491
# 30     9.89   0.753666   0.766261
# 31     9.78   0.812317   0.994348
# 33     9.45   0.765396   0.811879
# 34     9.90   0.753666   0.766261
# 35     9.61   0.633431   0.298683
# 36    10.00   0.354839  -0.784731
# 37     9.66   0.607038   0.196044
# 38     9.23   0.067449  -1.902358
# 41     9.45   0.372434  -0.716305
# 42     9.25   0.648094   0.355704
# 43     9.70   0.442815  -0.442600
# 44     9.70   0.513196  -0.168896
# 46     9.00   0.736070   0.697835
# 47     8.98   0.269795  -1.115457
# 48     9.10   0.413490  -0.556644
# 50     9.61   0.838710   1.096988
# 51     9.40   0.780059   0.868901
# 53     9.20   0.736070   0.697835
# 54     9.45   0.002933  -2.153254
# 55     9.80   0.601173   0.173235
# 56     9.13   0.363636  -0.750518
# 57     9.54   1.000000   1.724227
# 58     9.56   0.808355   0.978943
